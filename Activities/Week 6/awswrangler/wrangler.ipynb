# %%
pip install boto3
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import configparser
import boto3
import pandas as pd

# Import your credentials from your .cfg file
# YOUR CODE
config = configparser.ConfigParser()
config.read('aws.cfg')

aws_access_key = config['AWS']['aws_access_key_id']
aws_secret_key = config['AWS']['aws_secret_access_key']

# %%
# create an S3 client

s3 = boto3.client(
    's3',
    aws_access_key_id=aws_access_key,
    aws_secret_access_key=aws_secret_key
)

# %%
response = s3.list_buckets()
print('Existing buckets:')
for bucket in response['Buckets']:
    print(f'  {bucket["Name"]}')
# Out:
# Existing buckets:
#   alina-week6-bucket
#   amsu-aws-s3-assessment
#   amsu-s3-cf-website
#   andrea-lm-code-bucket
#   andy-wrangler-bucket
#   apiproject-build-bucket-su05297
#   aryan-techcatalyst-awswrangler-lab
#   aryan-techcatalyst-lab
#   austin-lambda-s3
#   aws-athena-query-results-535146832369-us-east-1
#   aws-athena-query-results-535146832369-us-east-2
#   aws-athena-query-results-535146832369-us-west-2
#   aws-athena-query-results-us-east-1-535146832369
#   aws-athena-query-results-us-east-1-535146832369nh
#   aws-athena-query-results-us-east-1-tarek
#   aws-athena-query-results-us-east-2-535146832369
#   aws-athena-query-results-us-east-2-535146832369-kb
#   aws-athena-query-results-us-east-2-535146832369ab
#   aws-cloudtrail-logs-535146832369-01f575cd
#   aws-cloudtrail-logs-535146832369-9d19bcae
#   aws-glue-assets-535146832369-us-east-1
#   aws-glue-assets-535146832369-us-east-2
#   aws-logs-535146832369-us-east-1
# ...

# %%
bucket_name = 'isabella.wrangler'
# if not us-east-1
location = {'LocationConstraint': 'us-west-2'}

# YOUR CODE TO CREATE A BUCKET
s3.create_bucket(
    Bucket = bucket_name,
    CreateBucketConfiguration= location
)
# Out:
# ---------------------------------------------------------------------------
# BucketAlreadyOwnedByYou                   Traceback (most recent call last)
# Cell In[8], line 6
#       3 location = {'LocationConstraint': 'us-west-2'}
#       5 # YOUR CODE TO CREATE A BUCKET
# ----> 6 s3.create_bucket(
#       7     Bucket = bucket_name,
#       8     CreateBucketConfiguration= location
#       9 )
#
# File ~/.python/current/lib/python3.10/site-packages/botocore/client.py:565, in ClientCreator._create_api_method.<locals>._api_call(self, *args, **kwargs)
#     561     raise TypeError(
#     562         f"{py_operation_name}() only accepts keyword arguments."
#     563     )
#     564 # The "self" in this scope is referring to the BaseClient.
# --> 565 return self._make_api_call(operation_name, kwargs)
#
# File ~/.python/current/lib/python3.10/site-packages/botocore/client.py:1021, in BaseClient._make_api_call(self, operation_name, api_params)
# ...

# %%
# UPLOAD_FILE CODE

key= 'file'

s3.upload_file('test.csv', bucket_name, 'file')

# %%
#PUT_OBJECT CODE

with open('test.csv', 'rb') as f:
    s3.put_object(Bucket=bucket_name, Key='test2', Body=f)

# %%
pip install awswrangler
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install numpy --upgrade
# Out:
# ...
#   Using cached numpy-2.0.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
# Using cached numpy-2.0.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (19.5 MB)
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# awswrangler 3.9.0 requires numpy<2.0,>=1.18; python_version < "3.12", but you have numpy 2.0.1 which is incompatible.
# ...

# %%
import awswrangler as wr

boto3.setup_default_session(
    aws_access_key_id= aws_access_key,
    aws_secret_access_key= aws_secret_key,
    region_name= 'us-east-1'
)

# %%
try:
    df = wr.s3.read_parquet('s3://techcatalyst-raw/yellow_tripdata_2024-01.parquet')
except Exception as e:
    print('error')
    print(e)

# %%
df.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         2  2024-01-01 00:57:55   2024-01-01 01:17:43                1
# 1         1  2024-01-01 00:03:00   2024-01-01 00:09:36                1
# 2         1  2024-01-01 00:17:06   2024-01-01 00:35:01                1
# 3         1  2024-01-01 00:36:38   2024-01-01 00:44:56                1
# 4         1  2024-01-01 00:46:51   2024-01-01 00:52:57                1
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           1.72           1                  N           186            79
# 1           1.80           1                  N           140           236
# 2           4.70           1                  N           236            79
# 3           1.40           1                  N            79           211
# 4           0.80           1                  N           211           148
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# ...

# %%
df.shape
# Out:
# (2964624, 19)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2964624 entries, 0 to 2964623
# Data columns (total 19 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   VendorID               Int32
#  1   tpep_pickup_datetime   datetime64[us]
#  2   tpep_dropoff_datetime  datetime64[us]
#  3   passenger_count        Int64
#  4   trip_distance          float64
#  5   RatecodeID             Int64
#  6   store_and_fwd_flag     string
#  7   PULocationID           Int32
#  8   DOLocationID           Int32
#  9   payment_type           Int64
#  10  fare_amount            float64
#  11  extra                  float64
#  12  mta_tax                float64
#  13  tip_amount             float64
#  14  tolls_amount           float64
#  15  improvement_surcharge  float64
#  16  total_amount           float64
#  17  congestion_surcharge   float64
#  18  Airport_fee            float64
# dtypes: Int32(3), Int64(3), datetime64[us](2), float64(10), string(1)
# ...

# %%
# complete the code
wr.s3.to_parquet(
    df= df,
    path= 's3://isabella.wrangler/yellow_tripdata_2024-01.parquet',
    dataset=True,
    mode= 'overwrite'
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 # complete the code
# ----> 2 wr.s3.to_parquet(
#       3     df= df,
#       4     path= 's3://isabella.wrangler/yellow_tripdata_2024-01.parquet',
#       5     dataset=True,
#       6     mode= 'overwrite'
#       7 )
#
# NameError: name 'wr' is not defined

# %%
databases = wr.catalog.databases()
print(databases)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 databases = wr.catalog.databases()
#       2 print(databases)
#
# NameError: name 'wr' is not defined

# %%
if "`isabella-awswrangler_test`" not in databases.values:
    wr.catalog.create_database(name='isabella-awswrangler_test')
    print(wr.catalog.databases())
else:
    print("Database awswrangler_test already exists")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 if "`isabella-awswrangler_test`" not in databases.values:
#       2     wr.catalog.create_database(name='isabella-awswrangler_test')
#       3     print(wr.catalog.databases())
#
# NameError: name 'databases' is not defined

# %%
tables = "isabella-rides"
print(tables)
# Out:
# isabella-rides

# %%
desc = "This the Taxi table for January, 2024."
param = {"source": "NYC Taxi Web Service https://www.nyc.gov", "class": "e-commerce"}
comments = {
    "tpep_pickup_datetime": "The date and time when the meter was engaged.",
    "PULocationID": "TLC Taxi Zone in which the taximeter was engaged",
    "payment_type": "A numeric code signifying how the passenger paid for the trip",
    "fare_amount": "The time-and-distance fare calculated by the meter.",
}

bucket = "techcatalyst-transformed-glue"

res = wr.s3.to_parquet(
    df=df,
    path=f"s3://{bucket}/isabella/nyc/",
    dataset=True,
    database="isabella-awswrangler_test",
    table="isabella-rides",
    mode="overwrite",
    glue_table_settings=wr.typing.GlueTableSettings(description=desc, parameters=param, columns_comments=comments),
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 12
#       3 comments = {
#       4     "tpep_pickup_datetime": "The date and time when the meter was engaged.",
#       5     "PULocationID": "TLC Taxi Zone in which the taximeter was engaged",
#       6     "payment_type": "A numeric code signifying how the passenger paid for the trip",
#       7     "fare_amount": "The time-and-distance fare calculated by the meter.",
#       8 }
#      10 bucket = "techcatalyst-transformed-glue"
# ---> 12 res = wr.s3.to_parquet(
#      13     df=df,
#      14     path=f"s3://{bucket}/isabella/nyc/",
#      15     dataset=True,
#      16     database="isabella-awswrangler_test",
#      17     table="isabella-rides",
#      18     mode="overwrite",
#      19     glue_table_settings=wr.typing.GlueTableSettings(description=desc, parameters=param, columns_comments=comments),
# ...
